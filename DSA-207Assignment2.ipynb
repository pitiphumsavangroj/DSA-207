# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import timedelta
# %matplotlib inline

# %%
from wordcloud import WordCloud, STOPWORDS
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-e0b3d4113260> in <module>
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#       2 import folium
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter(xdata, ydata, zdata, c=zdata, cmap='Greens')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Scatter3D')
# Out:
# Text(0.5, 0.92, 'Scatter3D')

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='winter')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax.view_init(60, 35)
fig

# %%
np.random.seed(10)
data = np.random.normal(100, 20, 200)
 
fig = plt.figure(figsize =(10, 7))
 
plt.boxplot(data)
 
plt.show()

# %%
np.random.seed(10)
 
data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]
 
fig = plt.figure(figsize =(10, 7))
 
ax = fig.add_axes([0, 0, 1, 1])
 
bp = ax.boxplot(data)
 
plt.show()

# %%
df = pd.read_csv('Bangkok.csv')
df.columns
# Out:
# Index(['Year', ' Month', ' Day', ' UTC Hour', ' PM2.5', ' PM10_mask',
#        ' Retrospective'],
#       dtype='object')

# %%
data_m5 = df[df[' Month']==5]

plt.figure(figsize =(10, 7))
sns.boxplot(y=' PM2.5', x='Year', data=data_m5, width=0.5, palette="colorblind")
plt.title("Seaborn box plt one category")
plt.suptitle("")
plt.xlabel("Year")
plt.ylabel("PM2.5")
plt.show()

# %%
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/customers.csv")
print(data.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data["Income"] = data[["Annual Income (k$)"]]
data["Spending"] = data[["Spending Score (1-100)"]]
data = data[["Income", "Spending"]]
print(data.head())
# Out:
#    Income  Spending
# 0      15        39
# 1      15        81
# 2      16         6
# 3      16        77
# 4      17        40

# %%
from sklearn.cluster import MeanShift

model = MeanShift(bandwidth=10)
model.fit(data)
pred = model.fit_predict(data)
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
plt.scatter(data["Income"], data["Spending"], c=pred, cmap='rainbow', alpha=0.9)
plt.show()

# %%
df = pd.read_csv('fishdata.csv', encoding='unicode_escape', header=None)
df.head()
# Out:
# C:\Users\Pitiphum Savangroj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        0    1   2   3     4     5   \
# 0  2020.0  6.0  18  14  30.0  33.0
# 1  2020.0  6.0  18  14  30.0  43.0
# 2  2020.0  6.0  18  14  30.0  48.0
# 3  2020.0  6.0  18  14  31.0   3.0
# 4  2020.0  6.0  18  14  31.0   8.0
#
#                                                   6     7     8     9   ...  \
# 0  qCBrs9¥ R! Â¤cäÍFóInitializing.... Please Wait!   NaN   NaN   NaN  ...
# 1                                                201  25.0  29.0  95.0  ...
# 2                                                201  25.0  29.0  95.0  ...
# 3                                                201  25.0  29.0  95.0  ...
# 4                                                201  25.0  29.0  95.0  ...
#
# ...

# %%
mylist = [*range(12,35)]
fish = df.drop(columns=mylist)

header = ['year', 'month', 'day', 'hour', 'minute', 'second', 'carbon monoxide', 'PM 2.5', 'external temp', 'humidity', 'internal temperature', 'ignore']
fish.columns = header
fish = fish.dropna()
fish.head()
# Out:
#      year  month  day  hour  minute  second carbon monoxide  PM 2.5  \
# 1  2020.0    6.0   18    14    30.0    43.0             201    25.0
# 2  2020.0    6.0   18    14    30.0    48.0             201    25.0
# 3  2020.0    6.0   18    14    31.0     3.0             201    25.0
# 4  2020.0    6.0   18    14    31.0     8.0             201    25.0
# 5  2020.0    6.0   18    14    31.0    13.0             201    25.0
#
#    external temp  humidity  internal temperature  ignore
# 1           29.0      95.0                 27.19    4.39
# 2           29.0      95.0                 27.19    4.38
# 3           29.0      95.0                 27.19    4.38
# 4           29.0      95.0                 27.19    4.41
# 5           29.0      95.0                 27.25    4.41

# %%
fish['year'] = fish['year'].astype('int64')
fish['month'] = fish['month'].astype('int64')
fish['minute'] = fish['minute'].astype('int64')
fish['second'] = fish['second'].astype('int64')
fish['carbon monoxide'] = pd.to_numeric(fish['carbon monoxide'], errors='coerce')
fish['carbon monoxide'] = fish['carbon monoxide'].astype('float64')
fish.dtypes
# Out:
# year                      int64
# month                     int64
# day                       int64
# hour                      int64
# minute                    int64
# second                    int64
# carbon monoxide         float64
# PM 2.5                  float64
# external temp           float64
# humidity                float64
# internal temperature    float64
# ignore                  float64
# dtype: object

# %%
fish.describe()
# Out:
#                year         month            day           hour  \
# count  8.057290e+05  8.057290e+05  805729.000000  805729.000000
# mean   2.038126e+03  2.580097e+00      18.485705      11.778356
# std    7.213832e+03  2.528976e+03      26.703259       6.193480
# min    2.140000e+02 -1.912020e+06       1.000000       0.000000
# 25%    2.020000e+03  7.000000e+00      13.000000       7.000000
# 50%    2.020000e+03  7.000000e+00      21.000000      12.000000
# 75%    2.020000e+03  8.000000e+00      26.000000      16.000000
# max    3.212020e+06  2.020000e+03   22020.000000      30.000000
#
#               minute         second  carbon monoxide         PM 2.5  \
# count  805729.000000  805729.000000    805729.000000  805729.000000
# mean       29.475378      29.499549       213.713183     -65.525206
# std        17.316288      17.320449        50.038140      66.753955
# min         0.000000       0.000000         0.000000    -240.000000
# ...

# %%
fish = fish[fish['year'] > 2000]
fish = fish[fish['year'] <= 2021]
fish.describe()
# Out:
#            year          month            day           hour         minute  \
# count  805671.0  805671.000000  805671.000000  805671.000000  805671.000000
# mean     2020.0       7.328162      18.446535      11.778117      29.476112
# std         0.0       1.083897       9.349752       6.193109      17.316194
# min      2020.0       6.000000       1.000000       0.000000       0.000000
# 25%      2020.0       7.000000      13.000000       7.000000      14.000000
# 50%      2020.0       7.000000      21.000000      12.000000      29.000000
# 75%      2020.0       8.000000      26.000000      16.000000      44.000000
# max      2020.0      10.000000      31.000000      23.000000      59.000000
#
#               second  carbon monoxide         PM 2.5  external temp  \
# count  805671.000000    805671.000000  805671.000000  805671.000000
# mean       29.499908       213.720037     -65.539228      30.476728
# std        17.320496        50.022856      66.720930       2.937920
# ...

# %%
fish = fish[fish['external temp'] > 0]
fish.describe()
# Out:
#            year          month            day           hour         minute  \
# count  805668.0  805668.000000  805668.000000  805668.000000  805668.000000
# mean     2020.0       7.328167      18.446525      11.778123      29.476079
# std         0.0       1.083896       9.349768       6.193120      17.316216
# min      2020.0       6.000000       1.000000       0.000000       0.000000
# 25%      2020.0       7.000000      13.000000       7.000000      14.000000
# 50%      2020.0       7.000000      21.000000      12.000000      29.000000
# 75%      2020.0       8.000000      26.000000      16.000000      44.000000
# max      2020.0      10.000000      31.000000      23.000000      59.000000
#
#               second  carbon monoxide         PM 2.5  external temp  humidity  \
# count  805668.000000    805668.000000  805668.000000  805668.000000  805668.0
# mean       29.499837       213.719741     -65.539104      30.480561      95.0
# ...

# %%
fdata = fish.head(30000)

# %%
from sklearn.cluster import MeanShift

model = MeanShift(bandwidth=50)
model.fit(fdata)
pred = model.fit_predict(fdata)

plt.figure(figsize=(12, 10))
plt.scatter(fdata['external temp'], fdata['humidity'], c=pred, cmap='plasma', alpha=0.9)
plt.show()

# %%
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')

xdata = fish['internal temperature']
ydata = fish['external temp']
zdata = fish['PM 2.5']

ax.scatter(xdata, ydata, zdata, c=zdata, cmap='autumn')
ax.set_xlabel('internal temperature')
ax.set_ylabel('external temperature')
ax.set_zlabel('PM 2.5')
ax.set_title('Scatter3D')
# Out:
# Text(0.5, 0.92, 'Scatter3D')

# %%
Z = fish.pivot_table(index='internal temperature', columns='external temp', values='PM 2.5').T.values
X_unique = np.sort(fish['internal temperature'].unique())
Y_unique = np.sort(fish['external temp'].unique())
X, Y = np.meshgrid(X_unique, Y_unique)

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')
ax.contour(X, Y, Z, 50, cmap='winter')
ax.set_xlabel('internal temperature')
ax.set_ylabel('external temperature')
ax.set_zlabel('PM 2.5')
ax.set_title('Contour3D')
# Out:
# Text(0.5, 0.92, 'Contour3D')

# %%
Z = fish.pivot_table(index='internal temperature', columns='external temp', values='PM 2.5').T.values
X_unique = np.sort(fish['internal temperature'].unique())
Y_unique = np.sort(fish['external temp'].unique())
X, Y = np.meshgrid(X_unique, Y_unique)

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, cmap='winter')
ax.set_xlabel('internal temperature')
ax.set_ylabel('external temperature')
ax.set_zlabel('PM 2.5')
ax.set_title('Contour3D')
# Out:
# Text(0.5, 0.92, 'Contour3D')
